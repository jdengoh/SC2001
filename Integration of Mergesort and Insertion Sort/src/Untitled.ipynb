# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Qn C(i)

# %% [markdown]
# ## Empirical Analysis

# %%
x1 = fixedS_data['n']
y1 = fixedS_data['Avg Key Comp']
y2 = fixedS_data['Avg Processing Time']

#print(len(y1))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(x1, y1)
axes[0].set_title('Average number of key comparisons vs Average n value')
axes[0].set_xlabel('Values of n')
axes[0].set_ylabel('Number of key comparisons')

axes[1].plot(x1, y2)
axes[1].set_title('Average number of key comparisons vs Average n value')
axes[1].set_xlabel('Values of n')
axes[1].set_ylabel('Number of key comparisons')
# Out:
# 20
# Text(0, 0.5, 'Number of key comparisons')

# %% [markdown]
# ## Theoratical Analysis

# %% [markdown]
# # Qn C(ii)

# %% [markdown]
# ## Empirical Analysis

# %%
fixedn_data = pd.read_csv("../csv_files/fixed_n_results.csv")
fixedn_data.tail()
# Out:
#      S  Avg Key Comp  Avg Processing Time
# 41  46    23183507.4             2.867801
# 42  47    23184270.6             2.725358
# 43  48    23188256.4             2.676784
# 44  49    23185637.8             2.763175
# 45  50    23184975.4             2.625678

# %%
x1 = fixedn_data['S']
y1 = fixedn_data['Avg Key Comp']
y2 = fixedn_data['Avg Processing Time']

#print(len(y1))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(x1, y1)
axes[0].set_title('Average number of key comparisons vs Average n value')
axes[0].set_xlabel('Values of n')
axes[0].set_ylabel('Number of key comparisons')

axes[1].plot(x1, y2)
axes[1].set_title('Average number of key comparisons vs Average n value')
axes[1].set_xlabel('Values of n')
axes[1].set_ylabel('Number of key comparisons')
# Out:
# Text(0, 0.5, 'Number of key comparisons')

# %% [markdown]
# ## Theoratical Analysis

# %% [markdown]
# # Qn C(iii)
